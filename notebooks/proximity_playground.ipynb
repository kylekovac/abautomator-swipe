# %%
from datetime import date, timedelta
import os
import pickle
import sys
import pandas as pd
import numpy as np
sys.path.append("..")

from abautomator.visualizer import BasicVisualizer, AbsDiffVisualizer, RelDiffVisualizer, utils
from abautomator.collector import Collector
from abautomator import config

from bokeh.io import output_notebook
from bokeh.plotting import show, save
# from bokeh.models import MultiChoice, CustomJS, Button
from bokeh.layouts import column, row

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1003">Loading BokehJS ...</span>
#     </div>

# %%
# %pip install -U pandas
# %pip install -r ../requirements.txt

# %%
name = "nan_analy"
# name = "proximity_analy"
analy = pickle.load(
    open(os.path.join("..", "tests", "cache", f"{name}.p"), "rb" )
)

# %%
# analy.base_df.head()

# %%
raw_df = analy.get_rel_diff_confidence_intervals()
pd.set_option('display.max_colwidth', None)
raw_df
# Out:
# STD Calc Assumption violation! N < 30 for a tx
# STD Calc Assumption violation! N < 30 for a tx
# STD Calc Assumption violation! N < 30 for a tx
# STD Calc Assumption violation! N < 30 for a tx
#       exp_cond            metric   tx_mean    tx_std  tx_count  ctrl_mean  \
# 0   Carousel03    n_all_sessions  1.111111  1.269296       9.0        1.0
# 1   Carousel03  pct_all_sessions  0.666667  0.500000       9.0        0.8
# 2      Video01    n_all_sessions  1.444444  2.127858       9.0        1.0
# 3      Video01  pct_all_sessions  0.777778  0.440959       9.0        0.8
# 4   Carousel02    n_all_sessions  1.166667  0.752773       6.0        1.0
# 5   Carousel02  pct_all_sessions  0.833333  0.408248       6.0        0.8
# 6   Carousel04    n_all_sessions  1.000000  0.577350       7.0        1.0
# 7   Carousel04  pct_all_sessions  0.857143  0.377964       7.0        0.8
# 8   Carousel01    n_all_sessions  1.142857  0.377964       7.0        1.0
# 9   Carousel01  pct_all_sessions  1.000000  0.000000       7.0        0.8
# 10     Video02    n_all_sessions  1.000000  0.000000       4.0        1.0
# 11     Video02  pct_all_sessions  1.000000  0.000000       4.0        0.8
#
#     ctrl_std  ctrl_count  abs_mean   abs_std   p_value  upper_68_ci  \
# 0   0.707107         5.0  0.111111  0.621296  0.861049    73.240672
# 1   0.447214         5.0 -0.133333  0.120736  0.134724    -1.574626
# 2   0.707107         5.0  0.444444  0.776586  0.597745   122.103083
# 3   0.447214         5.0 -0.022222  0.109664  0.419709    10.930249
# 4   0.707107         5.0  0.166667  0.443749  0.715923    61.041612
# 5   0.447214         5.0  0.033333  0.116291  0.387195    18.703079
# 6   0.707107         5.0  0.000000  0.370328  1.000000    37.032804
# 7   0.447214         5.0  0.057143  0.107583  0.297657    20.590716
# 8   0.707107         5.0  0.142857  0.312984  0.657830    45.584146
# 9   0.447214         5.0  0.200000       NaN       NaN          NaN
# 10  0.707107         5.0  0.000000       NaN       NaN          NaN
# 11  0.447214         5.0  0.200000       NaN       NaN          NaN
#
#     lower_68_ci  upper_95_ci  lower_95_ci       mean        std
# 0    -51.018450   132.885050  -110.662828  11.111111  62.129561
# 1    -31.758707    12.913732   -46.247066 -16.666667  15.092040
# 2    -33.214194   196.655377  -107.766488  44.444444  77.658639
# 3    -16.485804    24.089954   -29.645509  -2.777778  13.708026
# 4    -27.708279   103.641560   -70.308227  16.666667  44.374946
# 5    -10.369746    32.658035   -24.324702   4.166667  14.536412
# 6    -37.032804    72.584296   -72.584296   0.000000  37.032804
# 7     -6.305002    33.500660   -19.214946   7.142857  13.447859
# 8    -17.012718    75.630641   -47.059212  14.285714  31.298432
# 9           NaN          NaN          NaN  25.000000        NaN
# 10          NaN          NaN          NaN   0.000000        NaN
# 11          NaN          NaN          NaN  25.000000        NaN

# %%
# list(raw_df["metric"])
metric_list = list(raw_df["metric"])

# %%
# cond_order = ['proximity_weighted_algo']
cond_order = []

primary_metric_list = ['n_feed_views',
#  'pct_feed_views',
 'n_feed_taps',
#  'pct_feed_taps',
#  'n_all_feed_shares',
 'pct_all_feed_shares',
#  'n_direct_feed_shares',
#  'pct_direct_feed_shares',
#  'n_indirect_feed_shares',
#  'pct_indirect_feed_shares',
#  'n_signup_activation',
 'pct_signup_activation',
]
# 
secondary_metric_list = [
 'n_all_sessions',
 'pct_all_sessions',
 'n_organic_sessions',
 'pct_organic_sessions',
 'n_push_driven_sessions',
 'pct_push_driven_sessions',
 'n_incident_views',
 'pct_incident_views',
 'n_incident_share_attempts',
 'pct_incident_share_attempts',
]

guardrail_metric_list = [
 'n_chats',
 'pct_chats',
 'n_friend_invites',
 'pct_friend_invites',
 'n_trial_starts',
 'pct_trial_starts',
]

# %%
output_df = raw_df.sort_values(by=['abs_mean'], ascending=False)#[["metric", "abs_mean"]]
# output_df

# %%
df = utils.order_categories(output_df, metric_list, cond_order)
df = utils.remove_categories_w_no_order(df)
source = utils.convert_df_to_source(df)

vis = RelDiffVisualizer(source)
to_show = vis.get_layout()
show(to_show)
# Out:
# /opt/conda/lib/python3.9/site-packages/bokeh/models/plots.py:766: UserWarning:
# You are attempting to set `plot.legend.click_policy` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#   warnings.warn(_LEGEND_EMPTY_WARNING % attr)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-c56a45c2bfb2> in <module>
#       4
#       5 vis = RelDiffVisualizer(source)
# ----> 6 to_show = vis.get_layout()
#       7 show(to_show)
#
# ~/work/abautomator/visualizer/parent.py in get_layout(self)
#      49     def get_layout(self):
#      50
# ---> 51         fig = self.get_figure()
#      52
#      53         metric_options = utils.get_metric_options(self.source.data["metric"])
#
# ~/work/abautomator/visualizer/parent.py in get_figure(self)
#      43         bars.add_sig_bars(fig, self.source)
#      44
# ---> 45         self._setup_fig(fig)
#      46
#      47         return fig
#
# ~/work/abautomator/visualizer/parent.py in _setup_fig(self, fig)
#      27         utils.add_zero_span(fig)
#      28         utils.set_legend(fig)
# ---> 29         utils.set_x_axis(fig, self.x_axis_label, self.source)
#      30         utils.set_y_axis(fig)
#      31
#
# ~/work/abautomator/visualizer/utils.py in set_x_axis(fig, label, col_data_source)
#      69     fig.xaxis.axis_label = label
#      70     fig.xaxis.axis_label = label
# ---> 71     l_limit, r_limit = min(col_data_source.data["lower_95_ci"]), max(col_data_source.data["upper_95_ci"])
#      72     span = r_limit - l_limit
#      73     margin = span * 0.1
#
# ValueError: min() arg is an empty sequence

# %%
save(to_show, "/home/jovyan/work/notebooks/android-primary-metrics.html")
# Out:
# /opt/conda/lib/python3.9/site-packages/bokeh/io/saving.py:126: UserWarning: save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN
#   warn("save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN")
# /opt/conda/lib/python3.9/site-packages/bokeh/io/saving.py:139: UserWarning: save() called but no title was supplied and output_file(...) was never called, using default title 'Bokeh Plot'
#   warn("save() called but no title was supplied and output_file(...) was never called, using default title 'Bokeh Plot'")
# '/home/jovyan/work/notebooks/android-primary-metrics.html'

# %%
df = utils.order_categories(output_df, secondary_metric_list, cond_order)
df = utils.remove_categories_w_no_order(df)
source = utils.convert_df_to_source(df)

vis = RelDiffVisualizer(source)
to_show = vis.get_layout()
show(to_show)
# Out:
#   <div class="bk-root" id="21ee0c24-33e3-415e-bf93-2ff304f8f4a1" data-root-id="3170"></div>

# %%
save(to_show, "/home/jovyan/work/notebooks/android-secondary-metrics.html")
# Out:
# /opt/conda/lib/python3.9/site-packages/bokeh/io/saving.py:126: UserWarning: save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN
#   warn("save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN")
# /opt/conda/lib/python3.9/site-packages/bokeh/io/saving.py:139: UserWarning: save() called but no title was supplied and output_file(...) was never called, using default title 'Bokeh Plot'
#   warn("save() called but no title was supplied and output_file(...) was never called, using default title 'Bokeh Plot'")
# '/home/jovyan/work/notebooks/android-secondary-metrics.html'

# %%
df = utils.order_categories(output_df, guardrail_metric_list, cond_order)
df = utils.remove_categories_w_no_order(df)
source = utils.convert_df_to_source(df)

vis = RelDiffVisualizer(source)
to_show = vis.get_layout()
show(to_show)
# Out:
#   <div class="bk-root" id="3b62d742-bb82-4d4e-acdf-c238267a719c" data-root-id="3514"></div>

# %%
save(to_show, "/home/jovyan/work/notebooks/android-guardrail-metrics.html")
# Out:
# /opt/conda/lib/python3.9/site-packages/bokeh/io/saving.py:126: UserWarning: save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN
#   warn("save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN")
# /opt/conda/lib/python3.9/site-packages/bokeh/io/saving.py:139: UserWarning: save() called but no title was supplied and output_file(...) was never called, using default title 'Bokeh Plot'
#   warn("save() called but no title was supplied and output_file(...) was never called, using default title 'Bokeh Plot'")
# '/home/jovyan/work/notebooks/android-guardrail-metrics.html'
