# %%
from datetime import date, timedelta
import os
import pickle
import sys
import pandas as pd
import numpy as np
sys.path.append("..")

from abautomator.visualizer import BasicVisualizer, AbsDiffVisualizer, RelDiffVisualizer, utils
from abautomator.collector import Collector
from abautomator import config

from bokeh.io import output_notebook
from bokeh.plotting import show
# from bokeh.models import MultiChoice, CustomJS, Button
from bokeh.layouts import column, row

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1823">Loading BokehJS ...</span>
#     </div>

# %%
# %pip install -U pandas
# %pip install -r ../requirements.txt

# %%
# name = "rollback_analy"
name = "homescreen_analy_android"
analy = pickle.load(
    open(os.path.join("..", "tests", "cache", f"{name}.p"), "rb" )
)

df = analy.get_rel_diff_confidence_intervals()

# %%
pd.set_option('display.max_colwidth', None)
df
# Out:
#      exp_cond                                                          metric  \
# 0  Tx02112022    n_incident_share_attempts\n(shared_button:_incident_details)
# 1  Tx02112022  pct_incident_share_attempts\n(shared_button:_incident_details)
# 2  Tx02112022                         n_incident_share_attempts\n(screenshot)
# 3  Tx02112022                       pct_incident_share_attempts\n(screenshot)
# 4  Tx02112022         n_incident_share_attempts\n(invite_friends:_onboarding)
# 5  Tx02112022       pct_incident_share_attempts\n(invite_friends:_onboarding)
# 6  Tx02112022               n_incident_share_attempts\n(shared_button:_other)
# 7  Tx02112022             pct_incident_share_attempts\n(shared_button:_other)
# 8  Tx02112022               n_incident_share_attempts\n(invite_friends:_menu)
# 9  Tx02112022             pct_incident_share_attempts\n(invite_friends:_menu)
#
#     tx_mean    tx_std  tx_count  ctrl_mean  ctrl_std  ctrl_count  abs_mean  \
# 0  0.100595  0.771161  126507.0   0.092682  0.744197    390671.0  0.007914
# 1  0.061388  0.240041  126507.0   0.058082  0.233899    390671.0  0.003306
# 2  0.154521  1.853062  126507.0   0.146755  1.558165    390671.0  0.007766
# 3  0.071901  0.258325  126507.0   0.069583  0.254443    390671.0  0.002318
# 4  0.084209  6.873541  126507.0   0.069020  3.917126    390671.0  0.015189
# 5  0.061514  0.240272  126507.0   0.059764  0.237049    390671.0  0.001751
# 6  0.088019  0.860253  126507.0   0.035227  0.463320    390671.0  0.052792
# 7  0.031674  0.175132  126507.0   0.025134  0.156531    390671.0  0.006540
# 8  0.000166  0.014057  126507.0   0.000064  0.009191    390671.0  0.000102
# 9  0.000150  0.012254  126507.0   0.000054  0.007332    390671.0  0.000096
#
#     abs_std        p_value  upper_68_ci  lower_68_ci  upper_95_ci  \
# 0  0.002429   1.122152e-03    11.159355     5.917737    13.675332
# 1  0.000327   2.808355e-24     6.255188     5.127961     6.796256
# 2  0.005290   1.420754e-01     8.896192     1.687277    12.356472
# 3  0.000355   3.335363e-11     3.842117     2.821347     4.332086
# 4  0.015564   3.290942e-01    44.556223    -0.542517    66.203619
# 5  0.000331   6.015829e-08     3.482485     2.375707     4.013739
# 6  0.001895  1.142924e-170   155.244456   144.485382   160.408811
# 7  0.000224  3.141564e-187    26.915094    25.130259    27.771815
# 8  0.000034   2.903495e-03   212.934387   105.872698   264.323998
# 9  0.000012   1.558394e-15   202.152052   156.653766   223.991229
#
#    lower_95_ci        mean        std
# 0     3.401760    8.538546   2.620809
# 1     4.586893    5.691574   0.563613
# 2    -1.773003    5.291735   3.604458
# 3     2.331377    3.331732   0.510385
# 4   -22.189912   22.006853  22.549370
# 5     1.844454    2.929096   0.553389
# 6   139.321026  149.864919   5.379537
# 7    24.273539   26.022677   0.892417
# 8    54.483088  159.403543  53.530845
# 9   134.814589  179.402909  22.749143

# %%
df["metric"][0]
# Out:
# 'n_incident_share_attempts\n(shared_button:_incident_details)'

# %%
# metric_order = ['n_all_sessions', 'n_organic_sessions', 'n_push_driven_sessions', 'n_incident_views', 'n_incident_shares', 'pct_incident_shares']
# metric_order = ['n_incident_views', 'n_incident_share_completes', 'pct_incident_share_completes', 'n_incident_share_attempts', 'pct_incident_share_attempts']
metric_order = [
    'n_incident_share_attempts\n(shared_button:_incident_details)',
    'n_incident_share_attempts\n(screenshot)',
    'n_incident_share_attempts\n(shared_button:_other)',
    'n_incident_share_attempts\n(invite_friends:_menu)',
    'pct_incident_share_attempts\n(invite_friends:_onboarding)',
    
]
cond_order = ['Tx02112022']

df = utils.order_categories(df, metric_order, cond_order)
df = utils.remove_categories_w_no_order(df)
source = utils.convert_df_to_source(df)

vis = RelDiffVisualizer(source)
to_show = vis.get_layout()
show(to_show)
# Out:
#   <div class="bk-root" id="d9189130-6eca-4666-927e-eb7c234b98fa" data-root-id="1913"></div>

# %%
# name = "rollback_analy"
name = "homescreen_analy_ios"
analy = pickle.load(
    open(os.path.join("..", "tests", "cache", f"{name}.p"), "rb" )
)

df = analy.get_rel_diff_confidence_intervals()

# %%
metric_order = ['n_all_sessions', 'n_organic_sessions', 'n_push_driven_sessions', 'n_incident_views', 'n_incident_shares', 'pct_incident_shares']
cond_order = ['Tx02092022']

df = utils.order_categories(df, metric_order, cond_order)
df = utils.remove_categories_w_no_order(df)
source = utils.convert_df_to_source(df)

# %%
vis = RelDiffVisualizer(source)
to_show = vis.get_layout()
show(to_show)
# Out:
#   <div class="bk-root" id="0e30def4-17b0-4cfa-9198-23f8ce73f10c" data-root-id="1092"></div>

# %%
# name = "rollback_analy"
name = "homescreen_analy_android"
analy = pickle.load(
    open(os.path.join("..", "tests", "cache", f"{name}.p"), "rb" )
)

df = analy.get_rel_diff_confidence_intervals()

metric_order = ['n_all_sessions', 'n_organic_sessions', 'n_push_driven_sessions', 'n_incident_views', 'n_incident_shares', 'pct_incident_shares']
cond_order = ['Tx02112022']

df = utils.order_categories(df, metric_order, cond_order)
df = utils.remove_categories_w_no_order(df)
source = utils.convert_df_to_source(df)

vis = RelDiffVisualizer(source)
to_show = vis.get_layout()
show(to_show)
